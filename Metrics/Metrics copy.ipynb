# %% [markdown]
# #This will be code to show the metrics and how the modle is performing

# %%
Confusion matrix

# %%
#view the image at link to understand what confusion matrix looks like and search up the terms if you all don't understand
display.Image("https://hackernoon.imgix.net/images/BYWRsHWtmGOUC5N4fwNhMqohMAC3-c9c3gxs.png", width=600)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 display.Image("https://hackernoon.imgix.net/images/BYWRsHWtmGOUC5N4fwNhMqohMAC3-c9c3gxs.png", width=600)
#
# AttributeError: 'function' object has no attribute 'Image'

# %% [markdown]
# #references for confusion matrix
# https://www.tutorialspoint.com/machine_learning/machine_learning_confusion_matrix.htm

# %%
    True Positives (TP) − It is the case when both actual class & predicted class of data point is 1.
    True Negatives (TN) − It is the case when both actual class & predicted class of data point is 0.
    False Positives (FP) − It is the case when actual class of data point is 0 & predicted class of data point is 1.
    False Negatives (FN) − It is the case when actual class of data point is 1 & predicted class of data point is 0.

# %%
#show confusion matrix for accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predicted)
print('Accuracy:', accuracy)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, predicted, labels=mlp.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=mlp.classes_)
disp.plot()
plt.show()

# %%
#another one make confusion matrix
from sklearn.metrics import confusion_matrix

# Actual values
y_actual = [0, 1, 0, 1, 1, 0, 0, 1, 1, 1]

# Predicted values
y_pred = [0, 1, 0, 1, 0, 1, 0, 0, 1, 1]

# Confusion matrix
cm = confusion_matrix(y_actual, y_pred)
print(cm)


#and then display using a heat map
import seaborn as sns

# Plot confusion matrix as heatmap
sns.heatmap(cm, annot=True, cmap='summer')

# %%
#another one
from sklearn.metrics import confusion_matrix
preds = gnb.predict(test)
cm = confusion_matrix(test, preds)
print(cm)

# %%
#Accuracy

# %% [markdown]
# References:
# https://www.tutorialspoint.com/machine_learning/machine_learning_classification_algorithms.htm

# %%
#We can find the accuracy of the model build in previous step by comparing the two arrays namely test_labels and preds.
#We will be using the accuracy_score() function to determine the accuracy.
from sklearn.metrics import accuracy_score
print(accuracy_score(test_labels,preds))
0.951754385965
