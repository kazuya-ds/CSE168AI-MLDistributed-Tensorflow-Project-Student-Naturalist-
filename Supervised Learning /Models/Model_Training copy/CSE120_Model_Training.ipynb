# %% [markdown]
# #References

# %% [markdown]
# [Tensorflow Model Setup Basis](https://www.tensorflow.org/tutorials/keras/classification)

# %% [markdown]
# #Importing YOLO and Tensorflow

# %%
import os
HOME = os.getcwd()
print(HOME)
# %pip install "ultralytics<=8.3.40" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.7/107.7 GB disk)

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

# %% [markdown]
# #Downloading Annotated Dataset from Roboflow and Display Images from Dataset

# %% [markdown]
# Downloads segmentation annotation dataset from Roboflow for CSV Tensorflow Object Detection, 240 images

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fRR5yHzztKnt7IweiQ9V")
project = rf.workspace("spotit").project("cse120-segmentation-9jfey")
version = project.version(12)
dataset = version.download("tensorflow")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to CSE120-Segmentation-12 in tensorflow:: 100%|██████████| 248/248 [00:00<00:00, 4376.64it/s]

# %% [markdown]
# Get segmentation annotation dataset from Roboflow for COCO Segmentation

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fRR5yHzztKnt7IweiQ9V")
project = rf.workspace("spotit").project("cse120-segmentation-9jfey")
version = project.version(12)
dataset = version.download("coco-segmentation")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Show photo from dataset

# %%
# Example: show the first image from dataset
image_path = dataset.location + "/content/CSE120-Segmentation-12/test/IMG_6835_JPG.rf.56c5a8732b3eb788253566b3906cbd96.jpg"  # adjust path & filename accordingly
img = Image.open(image_path)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#get images from database
#figure out how to do so
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Define model paramters

# %%
class_names1 = ['Low Wear', 'Medium Wear', 'High Wear']
class_names2 = ['Low Wear', 'Medium Wear', 'High Wear']

# %% [markdown]
# #Preprocessing Images

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, divide the values by 255. It's important that the training set and the testing set be preprocessed in the same way:

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# #YOLO Set Up

# %% [markdown]
# # TensorFlow Set Up

# %% [markdown]
# Define Classes

# %%
class_names2 = ['Low Wear', 'Medium Wear', 'High Wear']

# %% [markdown]
# Explore Data

# %% [markdown]
# See train, test shapes

# %%
#see how many images in dataset, pixel x pixel size
train_images.shape

#see how many labels in dataset
len(train_labels)

#see labels
train_labels

#test shape
test_images.shape

#see how many labels
len(test_labels)
